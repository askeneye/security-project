# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Data

# %%
# Opponent group letter 
group = 'M'

anon = pd.read_csv(f'anon_data_gaston.csv')
public_reg = pd.read_excel(f'public_data_register{group}.xlsx')
public_results = pd.read_excel(f'public_data_results{group}.xlsx')
# survey_list = pd.read_excel(f'survey_list{group}.xlsx')  # leaked names

print("Anon:", anon.shape)
print("Register:", public_reg.shape)
# print("Survey list:", survey_list.shape)
# Out:
# Anon: (200, 8)
# Register: (1495, 7)

# %%
anon.head()
# Out:
#       sex  evote   zip            education citizenship     marital_status  \
# 0  Female      0  2400     Higher education       Other      Never married
# 1  Female      0  2300    Primary education       Other  Married/separated
# 2    Male      1  2100    Primary education     Denmark      Never married
# 3  Female      0  2200  Secondary education     Denmark  Married/separated
# 4  Female      0  2400  Secondary education     Denmark  Married/separated
#
#    party age_band
# 0  Green    50-59
# 1    Red      70+
# 2  Green    18-29
# 3    Red    50-59
# 4  Green      70+

# %%
public_reg.head()
# Out:
#                         name     sex        dob   zip citizenship  \
# 0            Carter, Celeste  Female 2004-05-26  2100     Denmark
# 1          Vallie, Alexander    Male 2000-06-21  2300     Denmark
# 2  Juarez-Cervantes, Bryanna  Female 1999-02-26  2100     Denmark
# 3          el-Musa, Shaamikh    Male 2000-06-27  2200     Austria
# 4        Mikalson, Amber Lee  Female 2003-02-07  2400     Denmark
#
#       marital_status  last_voted
# 0      Never married           2
# 1      Never married           1
# 2  Married/separated           1
# 3      Never married           2
# 4      Never married           1

# %%
survey_list.head()
